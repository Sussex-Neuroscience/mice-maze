# %% [markdown]
# Need to check the stream name, fiber photometry data is saved under specific stream names depending on your rig setup (e.g., Fi1d, x405A, x465A, GCaM)

# %%
import tdt
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.animation as animation
import subprocess as sp
import imageio_ffmpeg
import os
import pandas as pd
import cv2
import random
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
folder = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\dopaminergic recordings\MickeyMouse-251205-113917"
data = tdt.read_block(folder)
print(data.streams.keys())
print(data.epocs.keys())
# Out:
# read from t=0s to t=3933.27s
# dict_keys(['_405A', '_465A', '_560B', '_405C', '_465C', '_560D', 'Fi1r', 'Fi2r'])
# dict_keys(['MTL_', 'Tick'])

# %%
# Reminder: Use your local C:\ path here if you have it!
block_path = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\dopaminergic recordings\MickeyMouse-251205-113917"

print("Scanning TDT block headers...")
# t1=0, t2=1 tells it to only load the first second of data, making it instant
data = tdt.read_block(block_path, t1=0, t2=1)

print("\n--- WHAT IS ACTUALLY IN THIS FILE? ---")
print("STREAMS (Continuous analog traces):", list(data.streams.keys()))
print("EPOCS (Discrete digital timestamps):", list(data.epocs.keys()))
# Out:
# Scanning TDT block headers...
# read from t=0s to t=1s
#
# --- WHAT IS ACTUALLY IN THIS FILE? ---
# STREAMS (Continuous analog traces): ['_405A', '_465A', '_560B', '_405C', '_465C', '_560D', 'Fi1r', 'Fi2r']
# EPOCS (Discrete digital timestamps): ['MTL_', 'Tick']

# %%
### This is the one!!!

# --- 1. SET PATH ---
block_path = r"C:\Users\shahd\OneDrive\Desktop\MickeyMouse-251205-113917"

# --- 2. LOAD EVERYTHING ---
print("Loading the complete TDT block...")
data = tdt.read_block(block_path)

# --- 3. EXTRACT DOPAMINE ---
print("Extracting Dopamine trace...")
ds = 100 # Downsample by 100x
trace_green = data.streams['_465A'].data[::ds]
fs = data.streams['_465A'].fs
time_vec = np.linspace(0, len(data.streams['_465A'].data) / fs, len(data.streams['_465A'].data))[::ds]

# --- 4. REBUILD THE RED STIMULUS TRACE FROM 'MTL_' ---
print("Rebuilding the stimulus square wave...")
onsets = data.epocs['MTL_'].onset
offsets = data.epocs['MTL_'].offset

# Create a flat array of zeros, then fill the active times with 1s
stimulus_wave = np.zeros_like(time_vec)
for on, off in zip(onsets, offsets):
    idx_on = np.searchsorted(time_vec, on)
    idx_off = np.searchsorted(time_vec, off)
    stimulus_wave[idx_on:idx_off] = 1

# --- 5. BUILD THE PLOT ---
print("Generating HTML...")
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                    vertical_spacing=0.05, row_heights=[0.8, 0.2])

# TOP: Green Dopamine
fig.add_trace(go.Scattergl(
    x=time_vec, y=trace_green, 
    mode='lines', name='Dopamine (_465A)', 
    line=dict(color='#00FF00', width=1.5)
), row=1, col=1)

# BOTTOM: Red Stimulus Wave
fig.add_trace(go.Scattergl(
    x=time_vec, y=stimulus_wave, 
    mode='lines', name='Sound Stimulus (MTL_)', 
    line=dict(color='#FF0000', width=2, shape='hv') # 'hv' makes it a perfect square wave
), row=2, col=1)

# Add the shaded cyan boxes to the top graph
for on, off in zip(onsets, offsets):
    fig.add_vrect(
        x0=on, x1=off,
        fillcolor="cyan", opacity=0.3, layer="below", line_width=0,
        row=1, col=1
    )

fig.update_layout(
    title="Final Session Trace: Dopamine with Auditory Stimuli",
    template="plotly_dark",
    hovermode="x unified"
)

fig.update_yaxes(title_text="Fluorescence", row=1, col=1)
fig.update_yaxes(title_text="State", tickvals=[0, 1], row=2, col=1)
fig.update_xaxes(title_text="Time (seconds)", row=2, col=1)

output_filename = "perfect_session_plot.html"
fig.write_html(output_filename)

print(f"\n🎉 SUCCESS! Open '{output_filename}'")
# Out:
# Loading the complete TDT block...
# read from t=0s to t=3933.27s
# Extracting Dopamine trace...
# Rebuilding the stimulus square wave...
# Generating HTML...
#
# 🎉 SUCCESS! Open 'perfect_session_plot.html'

# %% [markdown]
# #### Because of the photobleaching, we are going to plot $\frac{\Delta f}{f}$

# %%
#  1. SET PATH 
block_path = r"C:\Users\shahd\OneDrive\Desktop\MickeyMouse-251205-113917"

#  2. LOAD EVERYTHING 
print("Loading the complete TDT block...")
data = tdt.read_block(block_path)

#  3. EXTRACT DOPAMINE 
print("Extracting Dopamine trace...")
ds = 100 # Downsample
trace_green = data.streams['_465A'].data[::ds]
fs = data.streams['_465A'].fs
time_vec = np.linspace(0, len(data.streams['_465A'].data) / fs, len(data.streams['_465A'].data))[::ds]

#  4. CALCULATE DELTA F/F 
print("Calculating Delta F/F...")
# 1. Fit a 4th-degree polynomial curve to the data to find the photobleaching trend (F0)
p = np.polyfit(time_vec, trace_green, 4)
baseline_f0 = np.polyval(p, time_vec)

# 2. Apply the Delta F/F math: (F - F0) / F0
delta_f = (trace_green - baseline_f0) / baseline_f0

# 3. Multiply by 100 to turn it into a percentage
delta_f_percent = delta_f * 100

#  5. REBUILD THE RED STIMULUS TRACE 
print("Rebuilding the stimulus square wave...")
onsets = data.epocs['MTL_'].onset
offsets = data.epocs['MTL_'].offset

stimulus_wave = np.zeros_like(time_vec)
for on, off in zip(onsets, offsets):
    idx_on = np.searchsorted(time_vec, on)
    idx_off = np.searchsorted(time_vec, off)
    stimulus_wave[idx_on:idx_off] = 1

#  6. BUILD THE PLOT 
print("Generating HTML...")
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                    vertical_spacing=0.05, row_heights=[0.8, 0.2])

# TOP: Flattened Delta F/F Trace
fig.add_trace(go.Scattergl(
    x=time_vec, y=delta_f_percent, 
    mode='lines', name='Dopamine ΔF/F (%)', 
    line=dict(color='#00FF00', width=1.5)
), row=1, col=1)

# BOTTOM: Red Stimulus Wave
fig.add_trace(go.Scattergl(
    x=time_vec, y=stimulus_wave, 
    mode='lines', name='Sound Stimulus (MTL_)', 
    line=dict(color='#FF0000', width=2, shape='hv') 
), row=2, col=1)

# Add the shaded cyan boxes to the top graph
for on, off in zip(onsets, offsets):
    fig.add_vrect(
        x0=on, x1=off,
        fillcolor="cyan", opacity=0.3, layer="below", line_width=0,
        row=1, col=1
    )

fig.update_layout(
    title="Normalized Session: Dopamine ΔF/F with Auditory Stimuli",
    template="plotly_dark",
    hovermode="x unified"
)

# Notice the Y-axis label is now a percentage!
fig.update_yaxes(title_text="ΔF/F (%)", row=1, col=1)
fig.update_yaxes(title_text="State", tickvals=[0, 1], row=2, col=1)
fig.update_xaxes(title_text="Time (seconds)", row=2, col=1)

output_filename = "delta_f_plot.html"
fig.write_html(output_filename)

print(f"\n🎉 BOOM! Open '{output_filename}'")
# Out:
# Loading the complete TDT block...
# read from t=0s to t=3933.27s
# Extracting Dopamine trace...
# Calculating Delta F/F...
# Rebuilding the stimulus square wave...
# Generating HTML...
#
# 🎉 BOOM! Open 'delta_f_plot.html'

# %% [markdown]
# #### Extract the epochs (TTLs)

# %%
# 1. SET PATH 
block_path = r"C:\Users\shahd\OneDrive\Desktop\MickeyMouse-251205-113917"

# 2. LOAD EVERYTHING 
print("Loading the complete TDT block...")
data = tdt.read_block(block_path)

print("\nEPOC HUNTER ")
# Loop through every digital event found in the file
for epoc_name in data.epocs.keys():
    onsets = data.epocs[epoc_name].onset
    
    # Safely check if this event has 'offsets' (a turn-off time)
    try:
        offsets = data.epocs[epoc_name].offset
        if len(offsets) > 0 and len(onsets) > 0:
            # Calculate how long the first sound was
            duration = offsets[0] - onsets[0]
            print(f"{epoc_name}: Found {len(onsets)} onsets and {len(offsets)} offsets!")
            print(f"   -> Example: The first pulse lasted exactly {duration:.3f} seconds.\n")
        else:
            print(f"{epoc_name}: Found onsets, but the offsets array is empty.\n")
    except AttributeError:
        print(f"{epoc_name}: This is strictly a Pulse event. No offsets exist.\n")
# Out:
# Loading the complete TDT block...
# read from t=0s to t=3933.27s
#
# --- EPOC HUNTER ---
# ✅ MTL_: Found 145 onsets and 145 offsets!
#    -> Example: The first pulse lasted exactly 0.327 seconds.
#
# ✅ Tick: Found 3933 onsets and 3933 offsets!
#    -> Example: The first pulse lasted exactly 1.000 seconds.

# %%
#  1. USER SETTINGS 
block_path = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\dopaminergic recordings\MickeyMouse-251205-113917"

# Time frame of the overall video in seconds
start_time =  (18 * 60) + 15
end_time = (19 * 60) + 20   

# Sliding window settings
window_length = 5.0  # How many seconds of data to show on screen at once

# Stream and TTL names
stream_name = '_465A' # Your primary green signal
ttl_name = 'Tick'     # CHANGE THIS to your actual TTL key (e.g., 'PtA0', 'Tick')

# Video settings
video_filename = 'photometry_sliding_window.mp4'
fps = 30 # Pro-tip: Match this to your behavior camera's FPS!

#  2. LOAD DATA & TTLS 
print(f"Loading data from {start_time}s to {end_time}s...")
data = tdt.read_block(block_path, t1=start_time, t2=end_time)

# Extract trace
trace = data.streams[stream_name].data
time = np.linspace(start_time, end_time, len(trace))

# Extract TTL onsets AND offsets
onsets = data.epocs[ttl_name].onset
offsets = data.epocs[ttl_name].offset

# Safeguard: if the recording stopped mid-TTL, TDT might drop the last offset
if len(offsets) < len(onsets):
    offsets = np.append(offsets, time[-1])

#  3. SET UP THE PLOT (DARK MODE) 
plt.style.use('dark_background') # Makes everything black/white appropriately
fig, ax = plt.subplots(figsize=(10, 4))

ax.set_ylim(np.min(trace) - 0.05*abs(np.min(trace)), np.max(trace) + 0.05*abs(np.max(trace)))
ax.set_xlabel('Time (s)')
ax.set_ylabel('Fluorescence (a.u.)')
ax.set_title(f'Auditory Stimulus Responses')

# Remove top and right borders for a cleaner look
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Draw shaded regions for the TTLs
for on, off in zip(onsets, offsets):
    # Only draw if the TTL falls within our video timeframe
    if on < end_time and off > start_time:
        # Shaded gray box for the duration of the sound
        ax.axvspan(on, off, color='white', alpha=0.2, lw=0) 

# Create the line object (Green trace)
line, = ax.plot([], [], lw=2, color='#00FF00') # Bright neon green

#  4. ANIMATE AND SAVE 
duration = end_time - start_time
total_frames = int(fps * duration)
data_points_per_frame = len(trace) // total_frames

def init():
    line.set_data([], [])
    return line,

def animate(i):
    # Calculate the current "leading edge" of time
    current_time = start_time + (i / fps)
    
    # Calculate the trailing edge of the window
    window_start = max(start_time, current_time - window_length)
    
    # Update the x-axis limits to create the "sliding" effect
    ax.set_xlim(window_start, current_time)
    
    # Figure out how much data to plot up to this frame
    idx = min((i + 1) * data_points_per_frame, len(trace))
    
    # Optional: to save memory, only plot data within the current window
    # But for short videos (a few mins), plotting time[:idx] is totally fine
    line.set_data(time[:idx], trace[:idx])
    
    return line,

print("Generating sliding window animation... this will take a moment.")
# blit=False is REQUIRED here because we are dynamically changing the axes limits
ani = animation.FuncAnimation(fig, animate, init_func=init, 
                              frames=total_frames, interval=1000/fps, blit=False)

writer = animation.FFMpegWriter(fps=fps, bitrate=2500)
ani.save(video_filename, writer=writer)

print(f"Done! Video saved as {video_filename}")
plt.close()
# Out:
# Loading data from 1095s to 1160s...
# read from t=1095s to t=1160s
# Generating sliding window animation... this will take a moment.
# C:\Users\shahd\AppData\Local\Temp\ipykernel_26072\2873379336.py:80: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(window_start, current_time)
# Done! Video saved as photometry_sliding_window.mp4

# %% [markdown]
#  #### Get time points/ times of the most played rois

# %%
file = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\mouseK30_5_vocalisations_detailed_visits.csv"

df = pd.read_csv(file)
# df['sound_on_time'] = pd.to_datetime(df['sound_on_time'],unit='s')
# df['sound_off_time'] = pd.to_datetime(df['sound_off_time'],unit='s')

t0 = df.iat[9,4]
t0= t0 +3

df['sound_on_time'] = df['sound_on_time'] - t0
df['sound_off_time'] = df['sound_off_time'] - t0

on_minutes = (df['sound_on_time'] // 60).astype(int).astype(str)
on_seconds = (df['sound_on_time'] % 60).astype(int).astype(str)

# 2. Pad the seconds with a leading zero (so 5 becomes "05")
on_seconds = on_seconds.str.zfill(2)

# 3. Combine them with a colon
df["on_minutes"] = on_minutes + ":" + on_seconds

off_minutes = (df['sound_off_time'] // 60).astype(int).astype(str)
off_seconds = (df['sound_off_time'] % 60).astype(int).astype(str)

# 2. Pad the seconds with a leading zero (so 5 becomes "05")
off_seconds = off_seconds.str.zfill(2)

# 3. Combine them with a colon
df["off_minutes"] = off_minutes + ":" + off_seconds

pd.set_option('display.max_rows', None)
df.iloc[120:125] #.sort_values(by=['time_spent_seconds'], ascending=False)
# Out:
#      trial_ID ROI_visited                                           stimulus  \
# 120         2        ROI3  frequency:C:/Users/labuser/Downloads/vocalisat...
# 121         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 122         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 123         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 124         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
#
#      sound_on_time  sound_off_time  time_spent_seconds on_minutes off_minutes
# 120    1098.964453     1099.739880            0.775427      18:18       18:19
# 121    1105.305844     1115.139977            9.834133      18:25       18:35
# 122    1115.769453     1119.457007            3.687554      18:35       18:39
# 123    1129.641707     1130.520590            0.878883      18:49       18:50
# 124    1134.012284     1160.280530           26.268246      18:54       19:20

# %% [markdown]
# #### cut the full video in the start_time and end_time
# ##### but also check the full $\frac{\Delta f}{f}$ plot to see if you might want to take some more time, diva

# %%
ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()

# Times
start_time = (18*60) + 13
end_time = (19*60) + 20
duration = end_time - start_time  # Calculate the actual length of the clip (67.3s)

# Paths
video = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\mouseK30_5_time_2025-12-05_11_41_09.mp4"
target_path = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\c.mp4"

# The command
command = [
    ffmpeg_path,
    '-ss', str(start_time),  # Fast seek to the start
    '-i', video,             # Input file
    '-t', str(duration),     # Tell FFmpeg to stop after 67.3 seconds
    '-c', 'copy',            # Copy streams without re-encoding
    '-y',                    # Overwrite output if it exists
    target_path
]

# Run it
sp.call(command)
print("Done!")
# Out:
# Done!

# %% [markdown]
# ### draw the rois and output a video with visualisation of active ROI while visited

# %%
input_video = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\c.mp4"
output_video = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\c_withrois.mp4"

# %%
# --- CUSTOM ROI DRAWING TOOL ---
def draw_custom_rois(frame, max_rois=8):
    rois = []
    drawing = False
    start_pt = (-1, -1)
    temp_frame = frame.copy()
    display_frame = frame.copy()

    def mouse_callback(event, x, y, flags, param):
        nonlocal drawing, start_pt, temp_frame, display_frame, rois
        if len(rois) >= max_rois: return 

        if event == cv2.EVENT_LBUTTONDOWN:
            drawing = True
            start_pt = (x, y)
        elif event == cv2.EVENT_MOUSEMOVE:
            if drawing:
                temp_frame = display_frame.copy()
                cv2.rectangle(temp_frame, start_pt, (x, y), (255, 0, 0), 2)
                cv2.imshow("Draw 8 ROIs", temp_frame)
        elif event == cv2.EVENT_LBUTTONUP:
            drawing = False
            end_pt = (x, y)
            x_min, y_min = min(start_pt[0], end_pt[0]), min(start_pt[1], end_pt[1])
            w, h = abs(start_pt[0] - end_pt[0]), abs(start_pt[1] - end_pt[1])

            if w > 5 and h > 5:
                rois.append((x_min, y_min, w, h))
                cv2.rectangle(display_frame, (x_min, y_min), (x_min + w, y_min + h), (0, 255, 0), 2)
                cv2.putText(display_frame, f"ROI {len(rois)}", (x_min, y_min - 5), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                cv2.imshow("Draw 8 ROIs", display_frame)

            if len(rois) == max_rois:
                print("\n8 ROIs drawn! Press any key to start processing...")

    # --- NEW: Make the drawing window resizable ---
    cv2.namedWindow("Draw 8 ROIs", cv2.WINDOW_NORMAL) 
    cv2.imshow("Draw 8 ROIs", display_frame)
    cv2.setMouseCallback("Draw 8 ROIs", mouse_callback)

    while True:
        key = cv2.waitKey(1) & 0xFF
        if len(rois) >= max_rois:
            cv2.waitKey(0) 
            break
        if key == 27: 
            break

    cv2.destroyWindow("Draw 8 ROIs")
    return rois

# --- GENERATE EMPTY BACKGROUND ---
def get_empty_background(cap, total_frames, num_samples=30):
    print(f"Calculating empty background from {num_samples} random frames...")
    frames = []
    for _ in range(num_samples):
        fid = random.randint(0, total_frames - 1)
        cap.set(cv2.CAP_PROP_POS_FRAMES, fid)
        ret, frame = cap.read()
        if ret:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(gray)
            
    median_frame = np.median(frames, axis=0).astype(dtype=np.uint8)
    return median_frame

# --- MAIN PROCESSING ---
def process_video_rois(video_path, output_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    cap.set(cv2.CAP_PROP_POS_FRAMES, random.randint(0, total_frames - 1))
    ret, random_frame = cap.read()
    
    print("\nIMPORTANT: Draw the ROI where the mouse spends the most time FIRST!")
    rois = draw_custom_rois(random_frame, max_rois=8)
    
    if len(rois) == 0: return

    empty_bg = get_empty_background(cap, total_frames)

    # Patch ROI 1
    if len(rois) == 8:
        other_rois_pixels = []
        for (x, y, w, h) in rois[1:]:
            patch = empty_bg[y:y+h, x:x+w]
            other_rois_pixels.extend(patch.flatten())
            
        avg_bg_color = int(np.mean(other_rois_pixels))
        x1, y1, w1, h1 = rois[0]
        empty_bg[y1:y1+h1, x1:x1+w1] = avg_bg_color
        print(f"Patched ROI 1 background with average color: {avg_bg_color}")
        
        # --- NEW: Make the preview window resizable ---
        cv2.namedWindow("Patched Background", cv2.WINDOW_NORMAL)
        cv2.imshow("Patched Background", empty_bg)
        cv2.waitKey(0)
        cv2.destroyWindow("Patched Background")

    cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    print("Processing video...")

    while True:
        ret, frame = cap.read()
        if not ret: break 

        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        diff = cv2.absdiff(empty_bg, gray_frame)
        _, binary_mask = cv2.threshold(diff, 50, 255, cv2.THRESH_BINARY)

        for (x, y, w, h) in rois:
            roi_mask = binary_mask[y:y+h, x:x+w]
            white_pixels = cv2.countNonZero(roi_mask)
            total_pixels = w * h
            
            occupancy_ratio = white_pixels / total_pixels
            
            if occupancy_ratio > 0.50:
                color = (0, 255, 0) # Green
            else:
                color = (0, 0, 255) # Red
                
            cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)

        out.write(frame)

    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Done! Video saved to {output_path}")

# # --- RUN THE CODE ---
# input_video = "your_experiment_video.mp4" 
# output_video = "processed_output.mp4"

process_video_rois(input_video, output_video)
# Out:
# IMPORTANT: Draw the ROI where the mouse spends the most time FIRST!
#
# 8 ROIs drawn! Press any key to start processing...
# Calculating empty background from 30 random frames...
# Patched ROI 1 background with average color: 207
# Processing video...
# Done! Video saved to C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\c_withrois.mp4

# %% [markdown]
# #### Get the video of the dopaminergic sliding window (with TTLs)

# %%
# --- 1. SET PATH ---
block_path = r"C:\Users\shahd\OneDrive\Desktop\MickeyMouse-251205-113917"

# --- 2. LOAD DATA ---
print("Loading TDT block...")
data = tdt.read_block(block_path)

# --- 3. EXTRACT DOPAMINE & DELTA F/F ---
print("Calculating Delta F/F...")
ds = 100 
trace_green = data.streams['_465A'].data[::ds]
fs = data.streams['_465A'].fs

# Use the actual starting time provided by TDT headers
start_time_offset = data.streams['_465A'].start_time
time_vec = np.linspace(start_time_offset, start_time_offset + len(trace_green) / (fs/ds), len(trace_green))

print(f"DEBUG: Data starts at {time_vec[0]:.2f}s and ends at {time_vec[-1]:.2f}s")

# Delta F/F
p = np.polyfit(time_vec, trace_green, 4)
baseline_f0 = np.polyval(p, time_vec)
delta_f_percent = ((trace_green - baseline_f0) / baseline_f0) * 100

# --- 4. EXTRACT STIMULUS ---
onsets = data.epocs['MTL_'].onset
offsets = data.epocs['MTL_'].offset
stimulus_wave = np.zeros_like(time_vec)
for on, off in zip(onsets, offsets):
    idx_on = np.searchsorted(time_vec, on)
    idx_off = np.searchsorted(time_vec, off)
    stimulus_wave[idx_on:idx_off] = 1

# --- 5. YOUR SPECIFIC TIME WINDOW ---
user_start_time = 1185.0
user_end_time = 1258.0
window_width = 15.0  
fps = 30

# --- 6. SETUP PLOT ---
plt.style.use('dark_background')
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 7), gridspec_kw={'height_ratios': [3, 1]})

# Scale Y-axis SAFELY
mask = (time_vec >= user_start_time) & (time_vec <= user_end_time)
data_in_clip = delta_f_percent[mask]

if data_in_clip.size == 0:
    print(f"ERROR: Your chosen window ({user_start_time}-{user_end_time}) contains NO data!")
    print("Adjusting window to match available data automatically...")
    user_start_time = time_vec[0] + 10 # Start 10s into the real data
    user_end_time = user_start_time + 60
    mask = (time_vec >= user_start_time) & (time_vec <= user_end_time)
    data_in_clip = delta_f_percent[mask]

y_min, y_max = np.min(data_in_clip), np.max(data_in_clip)
ax1.set_ylim(y_min - 2, y_max + 2)
ax2.set_ylim(-0.2, 1.2)

# Plot full lines
line1, = ax1.plot(time_vec, delta_f_percent, color='#00FF00', lw=2)
line2, = ax2.step(time_vec, stimulus_wave, color='#FF0000', lw=2, where='post')

# Shading
for on, off in zip(onsets, offsets):
    if on > user_start_time - 30 and off < user_end_time + 30:
        ax1.axvspan(on, off, color='cyan', alpha=0.2, lw=0)

time_text = ax1.text(0.02, 0.90, '', transform=ax1.transAxes, color='white', fontweight='bold', fontsize=12)
ax1.set_ylabel('ΔF/F (%)')
ax2.set_ylabel('Sound')

# --- 7. ANIMATION ---
def update(i):
    current_time = user_start_time + (i / fps)
    ax1.set_xlim(current_time - window_width, current_time)
    ax2.set_xlim(current_time - window_width, current_time)
    time_text.set_text(f'Session Time: {current_time:.1f} s')
    return line1, line2, time_text

total_frames = int((user_end_time - user_start_time) * fps)
print(f"Rendering {total_frames} frames...")
ani = animation.FuncAnimation(fig, update, frames=total_frames, interval=1000/fps)

# Save
output_name = "MickeyMouse_Final_Video.mp4"
try:
    ani.save(output_name, writer='ffmpeg', fps=fps, dpi=150)
    print(f"Done! {output_name}")
except:
    ani.save("MickeyMouse_Final_Video.gif", writer='pillow', fps=fps)
# Out:
# Loading TDT block...
# read from t=0s to t=3933.27s
# Calculating Delta F/F...
# DEBUG: Data starts at 0.00s and ends at 3933.24s
# Rendering 2190 frames...
# Done! MickeyMouse_Final_Video.mp4

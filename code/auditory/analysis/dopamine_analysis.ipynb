# %%
# %pip install tdt numpy matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting tdt
#   Downloading tdt-0.7.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from matplotlib) (1.4.10rc0)
# Requirement already satisfied: packaging>=20.0 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from matplotlib) (3.3.0a1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading tdt-0.7.3-py3-none-any.whl (59 kB)
# Installing collected packages: tdt
# Successfully installed tdt-0.7.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Need to check the stream name, fiber photometry data is saved under specific stream names depending on your rig setup (e.g., Fi1d, x405A, x465A, GCaM)

# %%
import tdt

folder = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\dopaminergic recordings\MickeyMouse-251205-113917"
data = tdt.read_block(folder)
print(data.streams.keys())
print(data.epocs.keys())
# Out:
# read from t=0s to t=3933.27s
# dict_keys(['_405A', '_465A', '_560B', '_405C', '_465C', '_560D', 'Fi1r', 'Fi2r'])
# dict_keys(['MTL_', 'Tick'])

# %%
import tdt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# --- 1. USER SETTINGS ---
block_path = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\dopaminergic recordings\MickeyMouse-251205-113917"

# Time frame in seconds
start_time =  (18 * 60) + 15
end_time = (19 * 60) + 20

# Stream and TTL names
stream_name = '_465A' # Your primary green signal
ttl_name = 'Tick'     # CHANGE THIS to your actual TTL key (e.g., 'PtA0', 'Tick')

# Video settings
video_filename = 'photometry_with_TTLs.mp4'
fps = 30 
duration = 5 

# --- 2. LOAD DATA & TTLS ---
print(f"Loading data from {start_time}s to {end_time}s...")
data = tdt.read_block(block_path, t1=start_time, t2=end_time)

# Extract continuous trace
trace = data.streams[stream_name].data
time = np.linspace(start_time, end_time, len(trace))

# Extract TTL onsets and filter for the ones inside our time window
all_ttls = data.epocs[ttl_name].onset
ttls_in_window = [t for t in all_ttls if start_time <= t <= end_time]

# --- 3. SET UP THE PLOT ---
fig, ax = plt.subplots(figsize=(10, 4))
ax.set_xlim(start_time, end_time)
ax.set_ylim(np.min(trace) - 0.05*abs(np.min(trace)), np.max(trace) + 0.05*abs(np.max(trace)))
ax.set_xlabel('Time (s)')
ax.set_ylabel('Fluorescence (a.u.)')
ax.set_title(f'Fiber Photometry Trace with {ttl_name} Events')

# Draw static vertical lines for the TTLs in the background
for t in ttls_in_window:
    ax.axvline(x=t, color='red', linestyle='--', alpha=0.7, label='TTL Event' if t == ttls_in_window[0] else "")

# Add a legend if we have TTLs
if ttls_in_window:
    ax.legend(loc='upper right')

# Create the empty line object for the animation
line, = ax.plot([], [], lw=2, color='green')

# --- 4. ANIMATE AND SAVE ---
total_frames = fps * duration
data_points_per_frame = len(trace) // total_frames

def init():
    line.set_data([], [])
    return line,

def animate(i):
    idx = min((i + 1) * data_points_per_frame, len(trace))
    line.set_data(time[:idx], trace[:idx])
    return line,

print(f"Found {len(ttls_in_window)} TTL events in this window. Generating animation...")
ani = animation.FuncAnimation(fig, animate, init_func=init, 
                              frames=total_frames, interval=1000/fps, blit=True)

writer = animation.FFMpegWriter(fps=fps, metadata=dict(artist='Me'), bitrate=1800)
ani.save(video_filename, writer=writer)

print(f"Done! Video saved as {video_filename}")
plt.close()
# Out:
# Loading data from 1095s to 1160s...
# read from t=1095s to t=1160s
# Found 65 TTL events in this window. Generating animation...
# Done! Video saved as photometry_with_TTLs.mp4

# %%
import tdt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# --- 1. USER SETTINGS ---
block_path = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\dopaminergic recordings\MickeyMouse-251205-113917"

# Time frame of the overall video in seconds
start_time =  (18 * 60) + 15
end_time = (19 * 60) + 20   

# Sliding window settings
window_length = 5.0  # How many seconds of data to show on screen at once

# Stream and TTL names
stream_name = '_465A' # Your primary green signal
ttl_name = 'Tick'     # CHANGE THIS to your actual TTL key (e.g., 'PtA0', 'Tick')

# Video settings
video_filename = 'photometry_sliding_window.mp4'
fps = 30 # Pro-tip: Match this to your behavior camera's FPS!

# --- 2. LOAD DATA & TTLS ---
print(f"Loading data from {start_time}s to {end_time}s...")
data = tdt.read_block(block_path, t1=start_time, t2=end_time)

# Extract trace
trace = data.streams[stream_name].data
time = np.linspace(start_time, end_time, len(trace))

# Extract TTL onsets AND offsets
onsets = data.epocs[ttl_name].onset
offsets = data.epocs[ttl_name].offset

# Safeguard: if the recording stopped mid-TTL, TDT might drop the last offset
if len(offsets) < len(onsets):
    offsets = np.append(offsets, time[-1])

# --- 3. SET UP THE PLOT (DARK MODE) ---
plt.style.use('dark_background') # Makes everything black/white appropriately
fig, ax = plt.subplots(figsize=(10, 4))

ax.set_ylim(np.min(trace) - 0.05*abs(np.min(trace)), np.max(trace) + 0.05*abs(np.max(trace)))
ax.set_xlabel('Time (s)')
ax.set_ylabel('Fluorescence (a.u.)')
ax.set_title(f'Auditory Stimulus Responses')

# Remove top and right borders for a cleaner look
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Draw shaded regions for the TTLs
for on, off in zip(onsets, offsets):
    # Only draw if the TTL falls within our video timeframe
    if on < end_time and off > start_time:
        # Shaded gray box for the duration of the sound
        ax.axvspan(on, off, color='white', alpha=0.2, lw=0) 

# Create the line object (Green trace)
line, = ax.plot([], [], lw=2, color='#00FF00') # Bright neon green

# --- 4. ANIMATE AND SAVE ---
duration = end_time - start_time
total_frames = int(fps * duration)
data_points_per_frame = len(trace) // total_frames

def init():
    line.set_data([], [])
    return line,

def animate(i):
    # Calculate the current "leading edge" of time
    current_time = start_time + (i / fps)
    
    # Calculate the trailing edge of the window
    window_start = max(start_time, current_time - window_length)
    
    # Update the x-axis limits to create the "sliding" effect
    ax.set_xlim(window_start, current_time)
    
    # Figure out how much data to plot up to this frame
    idx = min((i + 1) * data_points_per_frame, len(trace))
    
    # Optional: to save memory, only plot data within the current window
    # But for short videos (a few mins), plotting time[:idx] is totally fine
    line.set_data(time[:idx], trace[:idx])
    
    return line,

print("Generating sliding window animation... this will take a moment.")
# blit=False is REQUIRED here because we are dynamically changing the axes limits
ani = animation.FuncAnimation(fig, animate, init_func=init, 
                              frames=total_frames, interval=1000/fps, blit=False)

writer = animation.FFMpegWriter(fps=fps, bitrate=2500)
ani.save(video_filename, writer=writer)

print(f"Done! Video saved as {video_filename}")
plt.close()
# Out:
# Loading data from 1095s to 1160s...
# read from t=1095s to t=1160s
# Generating sliding window animation... this will take a moment.
# C:\Users\shahd\AppData\Local\Temp\ipykernel_26072\2873379336.py:80: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(window_start, current_time)
# Done! Video saved as photometry_sliding_window.mp4

# %%
import pandas as pd

file = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\mouseK30_5_vocalisations_detailed_visits.csv"

df = pd.read_csv(file)
# df['sound_on_time'] = pd.to_datetime(df['sound_on_time'],unit='s')
# df['sound_off_time'] = pd.to_datetime(df['sound_off_time'],unit='s')

t0 = df.iat[9,4]
t0= t0 +3



df['sound_on_time'] = df['sound_on_time'] - t0
df['sound_off_time'] = df['sound_off_time'] - t0

on_minutes = (df['sound_on_time'] // 60).astype(int).astype(str)
on_seconds = (df['sound_on_time'] % 60).astype(int).astype(str)

# 2. Pad the seconds with a leading zero (so 5 becomes "05")
on_seconds = on_seconds.str.zfill(2)

# 3. Combine them with a colon
df["on_minutes"] = on_minutes + ":" + on_seconds

off_minutes = (df['sound_off_time'] // 60).astype(int).astype(str)
off_seconds = (df['sound_off_time'] % 60).astype(int).astype(str)

# 2. Pad the seconds with a leading zero (so 5 becomes "05")
off_seconds = off_seconds.str.zfill(2)

# 3. Combine them with a colon
df["off_minutes"] = off_minutes + ":" + off_seconds

pd.set_option('display.max_rows', None)
df #.sort_values(by=['time_spent_seconds'], ascending=False)
# Out:
#      trial_ID ROI_visited                                           stimulus  \
# 0           1   entrance2                                   Unknown_Stimulus
# 1           1        ROI3  frequency:0 | interval_type:silent_trial | int...
# 2           1        ROI4  frequency:0 | interval_type:silent_trial | int...
# 3           1        ROI5  frequency:0 | interval_type:silent_trial | int...
# 4           1        ROI6  frequency:0 | interval_type:silent_trial | int...
# 5           1   entrance1                                   Unknown_Stimulus
# 6           1        ROI1  frequency:0 | interval_type:silent_trial | int...
# 7           1        ROI2  frequency:0 | interval_type:silent_trial | int...
# 8           1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 9           1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 10          1        ROI1  frequency:0 | interval_type:silent_trial | int...
# 11          1        ROI2  frequency:0 | interval_type:silent_trial | int...
# 12          1        ROI2  frequency:0 | interval_type:silent_trial | int...
# 13          1        ROI2  frequency:0 | interval_type:silent_trial | int...
# 14          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 15          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 16          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 17          1        ROI4  frequency:0 | interval_type:silent_trial | int...
# 18          1   entrance2                                   Unknown_Stimulus
# 19          1   entrance1                                   Unknown_Stimulus
# 20          1   entrance2                                   Unknown_Stimulus
# 21          1   entrance2                                   Unknown_Stimulus
# 22          1   entrance1                                   Unknown_Stimulus
# 23          1   entrance2                                   Unknown_Stimulus
# 24          1   entrance1                                   Unknown_Stimulus
# 25          1   entrance2                                   Unknown_Stimulus
# 26          1   entrance1                                   Unknown_Stimulus
# 27          1   entrance2                                   Unknown_Stimulus
# 28          1   entrance2                                   Unknown_Stimulus
# 29          1   entrance2                                   Unknown_Stimulus
# 30          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 31          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 32          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 33          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 34          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 35          1        ROI1  frequency:0 | interval_type:silent_trial | int...
# 36          1        ROI1  frequency:0 | interval_type:silent_trial | int...
# 37          1        ROI1  frequency:0 | interval_type:silent_trial | int...
# 38          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 39          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 40          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 41          1   entrance2                                   Unknown_Stimulus
# 42          1   entrance1                                   Unknown_Stimulus
# 43          1   entrance1                                   Unknown_Stimulus
# 44          1   entrance1                                   Unknown_Stimulus
# 45          1   entrance1                                   Unknown_Stimulus
# 46          1   entrance1                                   Unknown_Stimulus
# 47          1   entrance2                                   Unknown_Stimulus
# 48          1        ROI5  frequency:0 | interval_type:silent_trial | int...
# 49          1        ROI6  frequency:0 | interval_type:silent_trial | int...
# 50          1        ROI6  frequency:0 | interval_type:silent_trial | int...
# 51          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 52          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 53          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 54          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 55          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 56          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 57          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 58          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 59          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 60          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 61          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 62          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 63          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 64          1        ROI2  frequency:0 | interval_type:silent_trial | int...
# 65          1        ROI2  frequency:0 | interval_type:silent_trial | int...
# 66          1        ROI2  frequency:0 | interval_type:silent_trial | int...
# 67          1        ROI2  frequency:0 | interval_type:silent_trial | int...
# 68          1   entrance2                                   Unknown_Stimulus
# 69          1   entrance2                                   Unknown_Stimulus
# 70          1   entrance1                                   Unknown_Stimulus
# 71          1   entrance2                                   Unknown_Stimulus
# 72          1   entrance2                                   Unknown_Stimulus
# 73          1   entrance1                                   Unknown_Stimulus
# 74          1   entrance1                                   Unknown_Stimulus
# 75          1   entrance1                                   Unknown_Stimulus
# 76          1   entrance1                                   Unknown_Stimulus
# 77          1   entrance1                                   Unknown_Stimulus
# 78          1   entrance2                                   Unknown_Stimulus
# 79          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 80          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 81          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 82          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 83          1        ROI4  frequency:0 | interval_type:silent_trial | int...
# 84          1        ROI4  frequency:0 | interval_type:silent_trial | int...
# 85          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 86          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 87          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 88          1        ROI6  frequency:0 | interval_type:silent_trial | int...
# 89          1        ROI7  frequency:0 | interval_type:silent_trial | int...
# 90          1   entrance2                                   Unknown_Stimulus
# 91          1   entrance2                                   Unknown_Stimulus
# 92          1   entrance2                                   Unknown_Stimulus
# 93          1   entrance1                                   Unknown_Stimulus
# 94          1   entrance1                                   Unknown_Stimulus
# 95          1   entrance2                                   Unknown_Stimulus
# 96          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 97          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 98          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 99          1        ROI8  frequency:0 | interval_type:silent_trial | int...
# 100         1   entrance2                                   Unknown_Stimulus
# 101         1   entrance1                                   Unknown_Stimulus
# 102         1   entrance2                                   Unknown_Stimulus
# 103         1   entrance2                                   Unknown_Stimulus
# 104         1   entrance2                                   Unknown_Stimulus
# 105         1   entrance2                                   Unknown_Stimulus
# 106         1   entrance1                                   Unknown_Stimulus
# 107         1   entrance2                                   Unknown_Stimulus
# 108         1        ROI5  frequency:0 | interval_type:silent_trial | int...
# 109         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 110         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 111         2   entrance1                                   Unknown_Stimulus
# 112         2   entrance1                                   Unknown_Stimulus
# 113         2   entrance1                                   Unknown_Stimulus
# 114         2   entrance2                                   Unknown_Stimulus
# 115         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 116         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 117         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 118         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 119         2        ROI2  frequency:C:/Users/labuser/Downloads/vocalisat...
# 120         2        ROI3  frequency:C:/Users/labuser/Downloads/vocalisat...
# 121         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 122         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 123         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 124         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 125         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 126         2   entrance1                                   Unknown_Stimulus
# 127         2   entrance1                                   Unknown_Stimulus
# 128         2   entrance2                                   Unknown_Stimulus
# 129         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 130         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 131         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 132         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 133         2        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 134         2        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 135         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 136         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 137         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 138         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 139         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 140         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 141         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 142         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 143         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 144         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 145         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 146         2        ROI3  frequency:C:/Users/labuser/Downloads/vocalisat...
# 147         2        ROI2  frequency:C:/Users/labuser/Downloads/vocalisat...
# 148         2        ROI2  frequency:C:/Users/labuser/Downloads/vocalisat...
# 149         2        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 150         2        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 151         2        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 152         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 153         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 154         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 155         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 156         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 157         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 158         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 159         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 160         2        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 161         2   entrance2                                   Unknown_Stimulus
# 162         2   entrance1                                   Unknown_Stimulus
# 163         2   entrance1                                   Unknown_Stimulus
# 164         2   entrance1                                   Unknown_Stimulus
# 165         3   entrance2                                   Unknown_Stimulus
# 166         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 167         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 168         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 169         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 170         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 171         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 172         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 173         4        ROI4  frequency:C:/Users/labuser/Downloads/vocalisat...
# 174         4        ROI4  frequency:C:/Users/labuser/Downloads/vocalisat...
# 175         4   entrance2                                   Unknown_Stimulus
# 176         4   entrance1                                   Unknown_Stimulus
# 177         4   entrance1                                   Unknown_Stimulus
# 178         4   entrance1                                   Unknown_Stimulus
# 179         4   entrance2                                   Unknown_Stimulus
# 180         4   entrance1                                   Unknown_Stimulus
# 181         4   entrance2                                   Unknown_Stimulus
# 182         4   entrance2                                   Unknown_Stimulus
# 183         4   entrance2                                   Unknown_Stimulus
# 184         4   entrance2                                   Unknown_Stimulus
# 185         4   entrance1                                   Unknown_Stimulus
# 186         4   entrance1                                   Unknown_Stimulus
# 187         4   entrance1                                   Unknown_Stimulus
# 188         4   entrance2                                   Unknown_Stimulus
# 189         4   entrance2                                   Unknown_Stimulus
# 190         4   entrance2                                   Unknown_Stimulus
# 191         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 192         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 193         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 194         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 195         4        ROI1  frequency:0 | interval_type:control | interval...
# 196         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 197         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 198         4        ROI2  frequency:C:/Users/labuser/Downloads/vocalisat...
# 199         4        ROI2  frequency:C:/Users/labuser/Downloads/vocalisat...
# 200         4        ROI5  frequency:C:/Users/labuser/Downloads/vocalisat...
# 201         4   entrance2                                   Unknown_Stimulus
# 202         4   entrance2                                   Unknown_Stimulus
# 203         4   entrance1                                   Unknown_Stimulus
# 204         4   entrance1                                   Unknown_Stimulus
# 205         4   entrance1                                   Unknown_Stimulus
# 206         4   entrance1                                   Unknown_Stimulus
# 207         4   entrance2                                   Unknown_Stimulus
# 208         4   entrance2                                   Unknown_Stimulus
# 209         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 210         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 211         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 212         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 213         4        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 214         4        ROI2  frequency:C:/Users/labuser/Downloads/vocalisat...
# 215         4        ROI2  frequency:C:/Users/labuser/Downloads/vocalisat...
# 216         5        ROI7  frequency:0 | interval_type:silent_trial | int...
# 217         5        ROI5  frequency:0 | interval_type:silent_trial | int...
# 218         5        ROI5  frequency:0 | interval_type:silent_trial | int...
# 219         5   entrance2                                   Unknown_Stimulus
# 220         5   entrance1                                   Unknown_Stimulus
# 221         5   entrance2                                   Unknown_Stimulus
# 222         5   entrance2                                   Unknown_Stimulus
# 223         5   entrance2                                   Unknown_Stimulus
# 224         5   entrance1                                   Unknown_Stimulus
# 225         5   entrance2                                   Unknown_Stimulus
# 226         5        ROI6  frequency:0 | interval_type:silent_trial | int...
# 227         5        ROI6  frequency:0 | interval_type:silent_trial | int...
# 228         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 229         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 230         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 231         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 232         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 233         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 234         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 235         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 236         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 237         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 238         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 239         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 240         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 241         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 242         6        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 243         6        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 244         6        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 245         6        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 246         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 247         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 248         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 249         6        ROI2  frequency:0 | interval_type:control | interval...
# 250         6        ROI2  frequency:0 | interval_type:control | interval...
# 251         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 252         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 253         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 254         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 255         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 256         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 257         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 258         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 259         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 260         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 261         6        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 262         6        ROI6  frequency:C:/Users/labuser/Downloads/vocalisat...
# 263         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 264         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 265         6   entrance2                                   Unknown_Stimulus
# 266         6   entrance1                                   Unknown_Stimulus
# 267         6   entrance2                                   Unknown_Stimulus
# 268         6   entrance2                                   Unknown_Stimulus
# 269         6   entrance1                                   Unknown_Stimulus
# 270         6   entrance1                                   Unknown_Stimulus
# 271         6   entrance1                                   Unknown_Stimulus
# 272         6   entrance2                                   Unknown_Stimulus
# 273         6   entrance2                                   Unknown_Stimulus
# 274         6   entrance2                                   Unknown_Stimulus
# 275         6   entrance2                                   Unknown_Stimulus
# 276         6   entrance1                                   Unknown_Stimulus
# 277         6   entrance1                                   Unknown_Stimulus
# 278         6   entrance2                                   Unknown_Stimulus
# 279         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 280         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 281         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 282         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 283         6        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 284         6        ROI2  frequency:0 | interval_type:control | interval...
# 285         6        ROI2  frequency:0 | interval_type:control | interval...
# 286         7   entrance2                                   Unknown_Stimulus
# 287         7        ROI1  frequency:0 | interval_type:silent_trial | int...
# 288         7        ROI1  frequency:0 | interval_type:silent_trial | int...
# 289         7        ROI1  frequency:0 | interval_type:silent_trial | int...
# 290         7   entrance2                                   Unknown_Stimulus
# 291         7   entrance2                                   Unknown_Stimulus
# 292         7   entrance1                                   Unknown_Stimulus
# 293         7   entrance1                                   Unknown_Stimulus
# 294         7   entrance1                                   Unknown_Stimulus
# 295         7   entrance1                                   Unknown_Stimulus
# 296         7   entrance2                                   Unknown_Stimulus
# 297         7   entrance2                                   Unknown_Stimulus
# 298         7   entrance2                                   Unknown_Stimulus
# 299         7   entrance2                                   Unknown_Stimulus
# 300         7   entrance1                                   Unknown_Stimulus
# 301         8   entrance2                                   Unknown_Stimulus
# 302         8        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 303         8        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 304         8        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 305         8        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 306         8        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 307         8        ROI7  frequency:C:/Users/labuser/Downloads/vocalisat...
# 308         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 309         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 310         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 311         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 312         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 313         8   entrance2                                   Unknown_Stimulus
# 314         8   entrance1                                   Unknown_Stimulus
# 315         8   entrance1                                   Unknown_Stimulus
# 316         8   entrance2                                   Unknown_Stimulus
# 317         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 318         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 319         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 320         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 321         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 322         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 323         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 324         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 325         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 326         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 327         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 328         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 329         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 330         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 331         8        ROI5  frequency:C:/Users/labuser/Downloads/vocalisat...
# 332         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 333         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 334         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 335         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 336         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 337         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 338         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 339         8        ROI1  frequency:C:/Users/labuser/Downloads/vocalisat...
# 340         9        ROI7  frequency:0 | interval_type:silent_trial | int...
# 341         9        ROI7  frequency:0 | interval_type:silent_trial | int...
# 342         9        ROI7  frequency:0 | interval_type:silent_trial | int...
# 343         9        ROI7  frequency:0 | interval_type:silent_trial | int...
#
#      sound_on_time  sound_off_time  time_spent_seconds on_minutes off_minutes
# 0        -3.350220       -3.090255            0.259966      -1:56       -1:56
# 1        -3.345197       -3.090255            0.254943      -1:56       -1:56
# 2        -3.342810       -3.090255            0.252555      -1:56       -1:56
# 3        -3.340811       -3.090255            0.250556      -1:56       -1:56
# 4        -3.336809       -3.076107            0.260703      -1:56       -1:56
# 5        -3.352890       -3.005999            0.346891      -1:56       -1:56
# 6        -3.348221       -3.004993            0.343227      -1:56       -1:56
# 7        -3.346220       -3.003002            0.343219      -1:56       -1:56
# 8        -3.332178       -3.001003            0.331175      -1:56       -1:56
# 9        -3.329792       -3.000000            0.329792      -1:56       -1:57
# 10       -2.851848       -2.440946            0.410903      -1:57       -1:57
# 11       15.576049       16.543156            0.967107       0:15        0:16
# 12       17.527702       19.431604            1.903902       0:17        0:19
ip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import imageio_ffmpeg
import subprocess as sp

# %%
# %pip install moviepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting moviepy
#   Downloading moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from moviepy) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: numpy>=1.25.0 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from moviepy) (1.26.4)
# Collecting proglog<=1.0.0 (from moviepy)
#   Downloading proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from moviepy) (11.3.0)
# Requirement already satisfied: tqdm in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from proglog<=1.0.0->moviepy) (4.67.1)
# Requirement already satisfied: colorama in c:\users\shahd\anaconda3\envs\dlc-clean\lib\site-packages (from tqdm->proglog<=1.0.0->moviepy) (0.4.6)
# Downloading moviepy-2.2.1-py3-none-any.whl (129 kB)
# Downloading proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv, proglog, moviepy
#
#    -------------------------- ------------- 2/3 [moviepy]
#    ---------------------------------------- 3/3 [moviepy]
#
# Successfully installed moviepy-2.2.1 proglog-0.1.12 python-dotenv-1.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import subprocess as sp
import imageio_ffmpeg
ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()

start_time =  (18 * 60) + 15
end_time = (19 * 60) + 20
video = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\mouseK30_5_time_2025-12-05_11_41_09.mp4"

target_path = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\c.mp4"

# ffmpeg_extract_subclip(video, start_time, end_time, target_path)
sp.call([ffmpeg_path, '-loglevel', 'quiet', '-ss', str(start_time), '-to', str(end_time), '-i', video, '-c', 'copy', f"{target_path}"])
# Out:
# 0

# %%
input_video = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\c.mp4"
output_video = r"C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\c_withrois.mp4"

# %%
import cv2
import random
import numpy as np

# --- CUSTOM ROI DRAWING TOOL (Unchanged) ---
def draw_custom_rois(frame, max_rois=8):
    rois = []
    drawing = False
    start_pt = (-1, -1)
    temp_frame = frame.copy()
    display_frame = frame.copy()

    def mouse_callback(event, x, y, flags, param):
        nonlocal drawing, start_pt, temp_frame, display_frame, rois
        if len(rois) >= max_rois: return 

        if event == cv2.EVENT_LBUTTONDOWN:
            drawing = True
            start_pt = (x, y)
        elif event == cv2.EVENT_MOUSEMOVE:
            if drawing:
                temp_frame = display_frame.copy()
                cv2.rectangle(temp_frame, start_pt, (x, y), (255, 0, 0), 2)
                cv2.imshow("Draw 8 ROIs", temp_frame)
        elif event == cv2.EVENT_LBUTTONUP:
            drawing = False
            end_pt = (x, y)
            x_min, y_min = min(start_pt[0], end_pt[0]), min(start_pt[1], end_pt[1])
            w, h = abs(start_pt[0] - end_pt[0]), abs(start_pt[1] - end_pt[1])

            if w > 5 and h > 5:
                rois.append((x_min, y_min, w, h))
                cv2.rectangle(display_frame, (x_min, y_min), (x_min + w, y_min + h), (0, 255, 0), 2)
                cv2.putText(display_frame, f"ROI {len(rois)}", (x_min, y_min - 5), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                cv2.imshow("Draw 8 ROIs", display_frame)

            if len(rois) == max_rois:
                print("\n8 ROIs drawn! Press any key to start processing...")

    cv2.imshow("Draw 8 ROIs", display_frame)
    cv2.setMouseCallback("Draw 8 ROIs", mouse_callback)

    while True:
        key = cv2.waitKey(1) & 0xFF
        if len(rois) >= max_rois:
            cv2.waitKey(0) 
            break
        if key == 27: 
            break

    cv2.destroyWindow("Draw 8 ROIs")
    return rois

# --- GENERATE EMPTY BACKGROUND (Unchanged) ---
def get_empty_background(cap, total_frames, num_samples=30):
    print(f"Calculating empty background from {num_samples} random frames...")
    frames = []
    for _ in range(num_samples):
        fid = random.randint(0, total_frames - 1)
        cap.set(cv2.CAP_PROP_POS_FRAMES, fid)
        ret, frame = cap.read()
        if ret:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(gray)
            
    median_frame = np.median(frames, axis=0).astype(dtype=np.uint8)
    return median_frame

# --- MAIN PROCESSING WITH YOUR PATCH HACK ---
def process_video_rois(video_path, output_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    cap.set(cv2.CAP_PROP_POS_FRAMES, random.randint(0, total_frames - 1))
    ret, random_frame = cap.read()
    
    # 1. Draw ROIs (DRAW THE PROBLEMATIC ONE FIRST!)
    print("\nIMPORTANT: Draw the ROI where the mouse spends the most time FIRST!")
    rois = draw_custom_rois(random_frame, max_rois=8)
    
    if len(rois) == 0: return

    # 2. Get the median background
    empty_bg = get_empty_background(cap, total_frames)

    # 3. THE FIX: Patch ROI 1 using the other 7 ROIs
    if len(rois) == 8:
        other_rois_pixels = []
        # Gather all pixels from ROI 2 through 8
        for (x, y, w, h) in rois[1:]:
            patch = empty_bg[y:y+h, x:x+w]
            other_rois_pixels.extend(patch.flatten())
            
        # Calculate the average color
        avg_bg_color = int(np.mean(other_rois_pixels))
        
        # Paint over ROI 1 (rois[0]) with this average color
        x1, y1, w1, h1 = rois[0]
        empty_bg[y1:y1+h1, x1:x1+w1] = avg_bg_color
        print(f"Patched ROI 1 background with average color: {avg_bg_color}")
        
        # Optional: Show the patched background so you can verify it worked
        cv2.imshow("Patched Background - Press any key to start video", empty_bg)
        cv2.waitKey(0)
        cv2.destroyWindow("Patched Background - Press any key to start video")

    # 4. Setup Video Writer
    cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    print("Processing video...")

    # 5. Process video
    while True:
        ret, frame = cap.read()
        if not ret: break 

        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        diff = cv2.absdiff(empty_bg, gray_frame)
        _, binary_mask = cv2.threshold(diff, 30, 255, cv2.THRESH_BINARY)

        for (x, y, w, h) in rois:
            roi_mask = binary_mask[y:y+h, x:x+w]
            white_pixels = cv2.countNonZero(roi_mask)
            total_pixels = w * h
            
            occupancy_ratio = white_pixels / total_pixels
            
            if occupancy_ratio > 0.50:
                color = (0, 255, 0) # Green
            else:
                color = (0, 0, 255) # Red
                
            cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)

        out.write(frame)

    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Done! Video saved to {output_path}")

# --- RUN THE CODE ---


process_video_rois(input_video, output_video)
# Out:
# IMPORTANT: Draw the ROI where the mouse spends the most time FIRST!
#
# 8 ROIs drawn! Press any key to start processing...
# Calculating empty background from 30 random frames...
# Patched ROI 1 background with average color: 232
# Processing video...
# Done! Video saved to C:\Users\shahd\Box\Awake Project\Maze data\Auditory experiments\dopamine recordings\vocalisations\time_2025-12-05_11_41_09mouseK30_5\c_withrois.mp4

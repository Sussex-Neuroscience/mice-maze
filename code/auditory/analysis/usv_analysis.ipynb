# %%
import soundfile as sf
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from scipy.interpolate import interp1d
import soundfile as sf
from scipy.signal import resample_poly, resample, spectrogram, butter, sosfilt
from pathlib import Path
import math

# %%
def plot_spectrogram(file_path, fmax=None, n_fft=1024):
    audio, fs = sf.read(file_path)
    # Collapse to mono
    if audio.ndim > 1:
        audio = audio[:,0]
    # Cap nperseg to signal length
    nperseg = min(n_fft, len(audio))
    hop_length = nperseg // 2
    noverlap   = nperseg - hop_length

    f, t, Sxx = signal.spectrogram(
        audio, fs=fs,
        nperseg=nperseg,
        noverlap=noverlap
    )
    Sdb = 10 * np.log10(Sxx + 1e-10)

    plt.pcolormesh(t, f, Sdb, shading='gouraud')
    if fmax:
        plt.ylim(0, fmax)
    plt.xlabel('Time [s]'); plt.ylabel('Frequency [Hz]')
    plt.colorbar(label='Intensity [dB]')
    plt.show()

# %%
#check metadata in bash
#ffprobe -i "C:/Users/aleja/OneDrive/Desktop/mice maze/mouse_vocalisation/mM27.18-individuality_run1_day2-2016-10-14_15-16-00_0003.wav"

#ffmpeg -i "C:/Users/aleja/OneDrive/Desktop/mice maze/mouse_vocalisation/Figure 3 Audio 1.mp4" -vn -acodec pcm_s16le -ar 44100 -ac 2 "C:/Users/aleja/OneDrive/Desktop/mice maze/mouse_vocalisation/Figure 3 Audio 1.wav"

# %%
import random
files_path = "C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/"
file_names = os.listdir(files_path)
rois_number= 8

stimuli=[]
    
for file in file_names: 
    stimuli.append(files_path +file)

dict_files = dict(zip(stimuli, file_names))

#here what we do is we check if the number of stimuli corresponds to the number of ROIs and adjusting the stimuli accordingly
if rois_number == len(stimuli):
    pass
# if there are more rois than stimuli, select random stimuli to repeat
elif rois_number > len(stimuli): 

    difference = rois_number - len(stimuli)
    for i in range(difference):
        stimuli.append(random.choice(stimuli))
else:
    stimuli = stimuli[:rois_number]


#the frequencies list will contain lists containing the 2 frequencies that make up the interval. 
frequencies =[]
interval_numerical_list = []
interval_string_names = []
sound_type = []
sounds_arrays = []

for i in stimuli:
    interval_numerical_list.append(0)
    interval_string_names.append("none")          
    sound_type.append("control")

    if i == "silent":
        frequencies.append(0)
        sounds_arrays.append([0,0])
    else: 
        frequencies.append(dict_files[i])


for index, i in enumerate(frequencies):
    print (index, i) 

#plot_spectrogram(diadic_social_interaction)
# Out:
# 0 dyadic_social_interaction.wav
# 1 male_male_interaction.wav
# 2 male_w_female_oestrus.wav
# 3 mousetube3BB89473_socialcomparison.wav
# 4 run1_day2_male_w_female_oestrus.wav
# 5 run3_day2-2_male_w_female_oestrus.wav
# 6 run3_day2_male_w_female_oestrus.wav
# 7 run3_day2-2_male_w_female_oestrus.wav

# %%
print(stimuli)
for i in stimuli:
    print(i)
# Out:
# ['C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/dyadic_social_interaction.wav', 'C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/male_male_interaction.wav', 'C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/male_w_female_oestrus.wav', 'C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/mousetube3BB89473_socialcomparison.wav', 'C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/run1_day2_male_w_female_oestrus.wav', 'C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/run3_day2-2_male_w_female_oestrus.wav', 'C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/run3_day2_male_w_female_oestrus.wav', 'C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/run3_day2-2_male_w_female_oestrus.wav']
# C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/dyadic_social_interaction.wav
# C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/male_male_interaction.wav
# C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/male_w_female_oestrus.wav
# C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/mousetube3BB89473_socialcomparison.wav
# C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/run1_day2_male_w_female_oestrus.wav
# C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/run3_day2-2_male_w_female_oestrus.wav
# C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/run3_day2_male_w_female_oestrus.wav
# C:/Users/labuser/Downloads/vocalisationzzzzzz/trimmed_vocalisations/run3_day2-2_male_w_female_oestrus.wav

# %%
file_path_mouse_fem_piss_1 = "C:/Users/aleja/OneDrive/Desktop/mice maze/mouse_vocalisation/mM27.18-individuality_run1_day2-2016-10-14_15-16-00_0003.wav"
#plot_spectrogram(file_path_mouse_fem_piss_1)

# %%
file_path_mouse_fem_piss_2 = "C:/Users/aleja/OneDrive/Desktop/mice maze/mouse_vocalisation/mM3.5individuality_run3_day2-2016-10-28_17-05-14_0020.wav"
#plot_spectrogram(file_path_mouse_fem_piss_1)

# %%
def plot_usv_spectrogram(wav_path,
                         n_fft=512,
                         hop_length=128,
                         fmin=1000,  # 20 kHz
                         fmax=120000, # 125 kHz
                         cmap='cividis'):
    # 1. Load audio
    data, fs = sf.read(wav_path)
    if data.ndim > 1:
        data = data.mean(axis=1)

    # 2. Compute spectrogram (power spectral density)
    f, t, Sxx = signal.spectrogram(
        data,
        fs=fs,
        window='hann',
        nperseg=n_fft,
        noverlap=n_fft - hop_length,
        scaling='spectrum',
        mode='magnitude'
    )

    # 3. Limit to your USV band and convert to dB
    idx = np.logical_and(f >= fmin, f <= fmax)
    Sdb = 20 * np.log10(Sxx[idx, :] + 1e-10)
    f = f[idx] / 1e3  # convert to kHz for plotting

    # 4. Plot
    plt.figure(figsize=(6, 2))
    plt.pcolormesh(t, f, Sdb, shading='gouraud', cmap=cmap)
    plt.ylim(fmin/1e3, fmax/1e3)
    plt.xlabel("Time (s)")
    plt.ylabel("Frequency (kHz)")
    plt.title("USV Spectrogram")
    plt.colorbar(label="Amplitude (dB)")
    plt.tight_layout()
    plt.show()

# %%
for iplot_usv_spectrogram(file_path_mouse_fem_piss_1, cmap = "viridis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f7e5da800e13> in <module>
# ----> 1 plot_usv_spectrogram(file_path_mouse_fem_piss_1, cmap = "viridis")
#
# NameError: name 'plot_usv_spectrogram' is not defined

# %%
def generate_voc_array(path_to_voc, sample_rate):
    '''this function retrieves the sound data from the .wav files and samples them down to a more readable 192KHz'''
    voc_sound_data = []
    voc, fs = sf.read(path_to_voc)

    if fs == sample_rate:
        #USVs might be sampled at 250KHz. Our sound card handles max 192KHz. Check for sample rate
        voc_sound_data.append([voc])

    elif fs > sample_rate: 
        # if sample rate is too high, we need to resample
        n_samples_new = int(len(voc) * sample_rate / fs)
        voc_resampled = resample(voc, n_samples_new)
        # Ensure dtype float32
        voc_resampled = voc_resampled.astype('float32')

        voc_sound_data.append(voc_resampled)
    else:
        print(f"The sample rate of this recording is {fs}, which is too low\n Please ensure that the fs is at least 192 KHz")

  
    return voc_sound_data

# %%
generate_voc_array(file_path_mouse_fem_piss_1, 192000)
# Out:
# [array([-0.00308822, -0.00015801, -0.00086481, ...,  0.00023772,
#         0.00545693, -0.000707  ], dtype=float32)]
# [array([-0.00308822, -0.00015801, -0.00086481, ...,  0.00023772,
#          0.00545693, -0.000707  ], dtype=float32)]

# %%
voc, fs = sf.read(file_path_mouse_fem_piss_1)
print(fs)
# Out:
# 300000

# %%
path_to_voc = stimuli[0]
target_fs= 192000

# 1. Load and resample
voc_192k, fs_orig = generate_voc_array(path_to_voc, target_fs)

# 2. For comparison, also load the original (300kHz) signal
voc_orig, _ = sf.read(path_to_voc)   # voc_orig is at 300 kHz

# 3. Compute spectrogram of both signals
#    We'll use a window length (nperseg) that is fine enough to see ultrasonic structure;
#    e.g. window = 1024 samples → time‐resolution ≈ 1024/300000 ≈ 3.4 ms,
#    freq‐resolution ≈ 300k/1024 ≈ 293 Hz. You can adjust nperseg/hop accordingly.

nperseg_orig = 1024
noverlap_orig = nperseg_orig // 2
f1, t1, Sxx1 = spectrogram(voc_orig, fs=fs_orig,
                           nperseg=nperseg_orig, noverlap=noverlap_orig,
                           scaling='density', mode='magnitude')

nperseg_new = 1024
noverlap_new = nperseg_new // 2
f2, t2, Sxx2 = spectrogram(voc_192k, fs=target_fs,
                           nperseg=nperseg_new, noverlap=noverlap_new,
                           scaling='density', mode='magnitude')

# 4. Plot side by side
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pcolormesh(t1, f1/1000, 20*np.log10(Sxx1+1e-12), shading='auto', cmap = "viridis")
plt.ylim(0, fs_orig/2/1000)  # up to Nyquist (150 kHz)
plt.title('Original Spectrogram (300 kHz)')
plt.xlabel('Time [s]')
plt.ylabel('Frequency [kHz]')
plt.colorbar(label='Magnitude [dB]')

plt.subplot(1, 2, 2)
plt.pcolormesh(t2, f2/1000, 20*np.log10(Sxx2+1e-12), shading='auto', cmap = "viridis")
plt.ylim(0, target_fs/2/1000)  # up to Nyquist (96 kHz)
plt.title('Resampled Spectrogram (192 kHz)')
plt.xlabel('Time [s]')
plt.ylabel('Frequency [kHz]')
plt.colorbar(label='Magnitude [dB]')

plt.tight_layout()
plt.show()
# Out:
# [array([ 0.03802307,  0.0357291 ,  0.04125354, ..., -0.00293857,
#        -0.0081427 , -0.01040685], dtype=float32)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 23
#      21 nperseg_new = 1024
#      22 noverlap_new = nperseg_new // 2
# ---> 23 f2, t2, Sxx2 = spectrogram(voc_192k, fs=target_fs,
#      24                            nperseg=nperseg_new, noverlap=noverlap_new,
#      25                            scaling='density', mode='magnitude')
#      27 # 4. Plot side by side
#      28 plt.figure(figsize=(12, 6))
#
# File c:\Users\labuser\anaconda3\Lib\site-packages\scipy\signal\_spectral_py.py:776, in spectrogram(x, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode)
#     772     raise ValueError(f'unknown value for mode {mode}, must be one of {modelist}')
#     774 # need to set default for nperseg before setting default for noverlap below
#     775 window, nperseg = _triage_segments(window, nperseg,
# --> 776                                    input_length=x.shape[axis])
#     778 # Less overlap than welch, so samples are more statisically independent
#     779 if noverlap is None:
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
def highpass_filter(signal, fs, cutoff=20000, order=5):
    """
    Apply a Butterworth high-pass filter at 'cutoff' Hz to 'signal' sampled at 'fs' Hz.
    Uses an order-'order' filter in SOS form for numerical stability.
    """
    # Design: cutoff normalized to Nyquist
    sos = butter(order, cutoff / (fs / 2), btype='highpass', output='sos')
    filtered = sosfilt(sos, signal)
    return filtered

# 1. Load and resample signals
voc_orig, fs_orig = sf.read(path_to_voc)
voc_192k, fs_new = generate_voc_array(path_to_voc, target_fs)

# 2. (Optional) Limit to first 60 seconds
max_samples_orig = min(len(voc_orig), fs_orig * 60)
max_samples_new = min(len(voc_192k), fs_new * 60)
voc_orig_60s = voc_orig[:max_samples_orig]
voc_192k_60s = voc_192k[:max_samples_new]

# 3. Apply high-pass filter at 20 kHz to each
voc_orig_hp = highpass_filter(voc_orig_60s, fs_orig, cutoff=20000, order=6)
voc_192k_hp = highpass_filter(voc_192k_60s, fs_new, cutoff=20000, order=6)

# 4. Compute spectrograms for filtered signals
nperseg = 1024
noverlap = nperseg // 2

f1_hp, t1_hp, Sxx1_hp = spectrogram(voc_orig_hp, fs=fs_orig,
                                    nperseg=nperseg, noverlap=noverlap,
                                    scaling='density', mode='magnitude')

f2_hp, t2_hp, Sxx2_hp = spectrogram(voc_192k_hp, fs=fs_new,
                                    nperseg=nperseg, noverlap=noverlap,
                                    scaling='density', mode='magnitude')

# 5. Plot side by side, focusing only on frequencies above 20 kHz
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pcolormesh(t1_hp, f1_hp/1000, 20 * np.log10(Sxx1_hp + 1e-12), shading='auto', cmap='viridis')
plt.ylim(20, fs_orig/2 / 1000)  # Start at 20 kHz
plt.xlim(0, min(60, t1_hp.max()))  # Up to 60 s
plt.title('Original HPF Spectrogram (>20 kHz)')
plt.xlabel('Time [s]')
plt.ylabel('Frequency [kHz]')
plt.colorbar(label='Magnitude [dB]')

plt.subplot(1, 2, 2)
plt.pcolormesh(t2_hp, f2_hp/1000, 20 * np.log10(Sxx2_hp + 1e-12), shading='auto', cmap='viridis')
plt.ylim(20, fs_new/2 / 1000)  # Start at 20 kHz
plt.xlim(0, min(60, t2_hp.max()))  # Up to 60 s
plt.title('Resampled HPF Spectrogram (>20 kHz)')
plt.xlabel('Time [s]')
plt.ylabel('Frequency [kHz]')
plt.colorbar(label='Magnitude [dB]')

plt.tight_layout()
plt.show()

# %%
target_fs = 192000
# Optional: where to save figures (set to None to disable)
save_dir = None  # e.g., r"C:/path/to/_figures"
if save_dir:
    save_dir = Path(save_dir)
    save_dir.mkdir(exist_ok=True)

# ──────────────────────────────────────────────────────────────────────────────
# Helper: down-mix to mono and pick window parameters
# ──────────────────────────────────────────────────────────────────────────────
def to_mono(x: np.ndarray) -> np.ndarray:
    return x.mean(axis=1) if x.ndim > 1 else x


def pick_params(sig_len: int, requested: int = 1024) -> tuple[int, int]:
    # Choose a power-of-two window ≤ sig_len
    if sig_len <= 16:
        return sig_len, max(sig_len // 2, 0)
    max_pow2 = 2 ** int(np.floor(np.log2(sig_len)))
    nperseg = min(requested, max_pow2)
    return nperseg, nperseg // 2

# ──────────────────────────────────────────────────────────────────────────────
# Plotting routine
# ──────────────────────────────────────────────────────────────────────────────

def plot_compare(original: np.ndarray,
                 resampled: np.ndarray,
                 fs_orig: int,
                 fs_new: int,
                 title: str) -> None:
    # Ensure mono
    original = to_mono(original.astype('float32'))
    resampled = to_mono(resampled.astype('float32'))

    # Use fixed window parameters for direct comparison
    nperseg = 1024
    noverlap = nperseg // 2

    # Compute spectrograms:
    #  - Original with its sample rate
    f1, t1, S1 = spectrogram(
        original, fs_orig, nperseg=nperseg, noverlap=noverlap,
        scaling='density', mode='magnitude'
    )
    #  - Resampled: compute with original fs to preserve time axis,
    #    then we'll restrict frequency display to new Nyquist
    f2_full, t2, S2_full = spectrogram(
        resampled, fs_orig, nperseg=nperseg, noverlap=noverlap,
        scaling='density', mode='magnitude'
    )
    # Restrict to frequencies up to new Nyquist (fs_new/2)
    nyquist = fs_new / 2
    mask = f2_full <= nyquist
    f2 = f2_full[mask]
    S2 = S2_full[mask, :]

    # Convert to dB
    S1_db = 20 * np.log10(S1 + 1e-12)
    S2_db = 20 * np.log10(S2 + 1e-12)

    # Plot side-by-side with shared axes
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharex=True, sharey=True)
    pcm1 = ax1.pcolormesh(t1, f1/1e3, S1_db, shading='auto')
    ax1.set_title('Original')
    ax1.set_xlabel('Time [s]'); ax1.set_ylabel('Frequency [kHz]')
    fig.colorbar(pcm1, ax=ax1, label='dB')

    pcm2 = ax2.pcolormesh(t2, f2/1e3, S2_db, shading='auto')
    ax2.set_title(f'Resampled ({fs_new/1000:.0f} kHz)')
    ax2.set_xlabel('Time [s]')
    # Limit y-axis to new Nyquist
    ax2.set_ylim(0, nyquist/1000)
    fig.colorbar(pcm2, ax=ax2, label='dB')
    fig.suptitle(title)
    fig.tight_layout()

    if save_dir:
        out_file = save_dir / f"{title.replace(' ', '_')}.png"
        fig.savefig(out_file, dpi=200)
    plt.show()


# ──────────────────────────────────────────────────────────────────────────────
# Main loop remains unchanged
for raw in stimuli:
    p = Path(raw).expanduser().resolve()
    if not p.is_file():
        print(f"Skipping missing: {p}")
        continue

    # Load and resample using existing helper
    raw_res, fs_orig = generate_voc_array(str(p), target_fs)
    # Unpack result, handle possible list wrapper
    if isinstance(raw_res, (list, tuple)):
        resampled = np.asarray(raw_res[0])
    else:
        resampled = np.asarray(raw_res)
    original, _ = sf.read(str(p))

    # Plot comparison
    plot_compare(original, resampled, fs_orig, target_fs, p.stem)
# Out:
# [array([ 0.03802307,  0.0357291 ,  0.04125354, ..., -0.00293857,
#        -0.0081427 , -0.01040685], dtype=float32)]
# [array([-0.05175903, -0.03323318, -0.02844155, ..., -0.01980921,
#         0.01061089,  0.01333587], dtype=float32)]
# [array([-1.3760465e-02, -7.7191698e-03,  3.0518446e-02, ...,
#         1.8371632e-02,  8.1485290e-05,  2.0628378e-02], dtype=float32)]
# [array([-0.003428  ,  0.00066531,  0.00287877, ..., -0.00438887,
#         0.00265551,  0.00423094], dtype=float32)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 102
#      99 original, _ = sf.read(str(p))
#     101 # Plot comparison
# --> 102 plot_compare(original, resampled, fs_orig, target_fs, p.stem)
#
# Cell In[39], line 69, in plot_compare(original, resampled, fs_orig, fs_new, title)
#      66 ax1.set_xlabel('Time [s]'); ax1.set_ylabel('Frequency [kHz]')
#      67 fig.colorbar(pcm1, ax=ax1, label='dB')
# ---> 69 pcm2 = ax2.pcolormesh(t2, f2/1e3, S2_db, shading='auto')
#      70 ax2.set_title(f'Resampled ({fs_new/1000:.0f} kHz)')
#      71 ax2.set_xlabel('Time [s]')
#
# File c:\Users\labuser\anaconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File c:\Users\labuser\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:6428, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6425 shading = shading.lower()
#    6426 kwargs.setdefault('edgecolors', 'none')
# -> 6428 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6429                                     shading=shading, kwargs=kwargs)
#    6430 coords = np.stack([X, Y], axis=-1)
#    6432 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
#
# File c:\Users\labuser\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:6019, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    6016             Y = _interp_grid(Y.T).T
#    6017         shading = 'flat'
# -> 6019 C = cbook.safe_masked_invalid(C, copy=True)
#    6020 return X, Y, C, shading
#
# File c:\Users\labuser\anaconda3\Lib\site-packages\matplotlib\cbook.py:733, in safe_masked_invalid(x, copy)
#     732 def safe_masked_invalid(x, copy=False):
# --> 733     x = np.array(x, subok=True, copy=copy)
#     734     if not x.dtype.isnative:
#     735         # If we have already made a copy, do the byteswap in place, else make a
#     736         # copy with the byte order swapped.
#     737         # Swap to native order.
#     738         x = x.byteswap(inplace=copy).view(x.dtype.newbyteorder('N'))
#
# KeyboardInterrupt:

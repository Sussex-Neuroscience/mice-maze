# %% [markdown]
# # Fitting the computational model of aesthetic value to the data
#
# In this worksheet I will try to see how to fit the computational model of aesthetic value by Brielmann & Dayan to my stimuli
# $$V(s) = \underbrace{\log p(s|X)}_{\text{1. Immediate Fluency}} + \underbrace{[D_{KL}(p_T || X_{new}) - D_{KL}(p_T || X)]}_{\text{2. Improvement in Prediction}}$$
#
# ### Here
#
# $$\log p(s|X)$$
#
# Is the **Likelihood**
